# %% [markdown]
# # Recommender System for Coaching and Academic Advising
# #### Goal of the system is to consider user interests and feedback to recommend specific courses based on their level.

# %%
#AUTHOR: Aubry, Nanae & Ruchti, Kilian
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import math
import os.path
from os import path

# %%
class color:
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %% [markdown]
# ## User enter name and topic choice

# %%
user_name = input(color.BOLD + color.UNDERLINE + "What is your name?" + color.END + " ")
# Out:
# What is your name? Bill

# %%
print("Topics:" + color.BOLD +  color.GREEN +  " \n Musical Instrument \n Business Finance" + color.END)
choice = input(color.BOLD + color.UNDERLINE + "What do you want to learn about?" + color.END + " ")
# Out:
# Topics:
#  Musical Instrument
#  Business Finance
# What do you want to learn about? Business

# %% [markdown]
# #### Read dataset of courses corresponding to the main topic user chose

# %%
topic = ""
main_topic_choice = choice.lower()

#Select csv to open based on user input
if 'music' in main_topic_choice:
    all_courses = pd.read_csv('data/music_courses.csv', header = 0, sep=',')
    topic = "music"
elif 'business' or 'finance' in main_topic_choice:
    all_courses = pd.read_csv('data/business_courses.csv', header = 0, sep=',')
    topic = "business"

all_courses.set_index(["course_title"], inplace=True)

# %% [markdown]
# #### Filter through courses to only show rows that are associated with specific subject

# %%
#Filter dataframe to find courses containing a keyword
def subjects_filter(subject_keywords):
    rc = all_courses.copy()
    filtered_resources = rc.loc[rc['specific_subject'].str.contains(subject_keywords)]
    return filtered_resources

# %% [markdown]
# ## Ask user what courses they would like and apply filter

# %%
if topic == 'music':
    print("Subjects:" + color.BOLD +  color.GREEN +  " \n Drums \n Guitar \n Piano \n Chords \n Harmonica \n Songs \n etc..." + color.END)
elif topic == 'business':
    print("Subjects:" + color.BOLD +  color.GREEN +  " \n Investment \n Trading \n Cryptocurrency \n Stock Market \n Analysis \n Accounting \n etc..." + color.END)

user_filter = input(color.BOLD + color.UNDERLINE + "What topics would you like to see?" + color.END + " ")
# Out:
# Subjects:
#  Investment
#  Trading
#  Cryptocurrency
#  Stock Market
#  Analysis
#  Accounting
#  etc...
# What topics would you like to see? Accounting

# %%
specific_subject = subjects_filter(user_filter)

# %% [markdown]
# #### Seperate the filtered data by level of difficulty

# %%
def levels_filter(filtered_courses):
    beginner = filtered_courses[filtered_courses["level"].isin({'Beginner Level'})]
    intermediate = filtered_courses[filtered_courses["level"].isin({'Intermediate Level'})]
    expert = filtered_courses[filtered_courses["level"].isin({'Expert Level'})]
   
    list_levels = list()
    list_levels.append(beginner)
    list_levels.append(intermediate)
    list_levels.append(expert)
    
    return list_levels

# %% [markdown]
# #### Read course_attributes dataset to create similarity matrix

# %%
if topic == "music":
    topic_attributes = pd.read_csv('data/music_attributes.csv', header=0, index_col="course_title")
if topic == "business":
    topic_attributes = pd.read_csv('data/business_attributes.csv', header=0, index_col="course_title")

# %% [markdown]
# #### Calculate Cosine Similarity Accross the Courses

# %% [markdown]
# ##### We are calculating the similarity by considering their subjects

# %%
def similarity_matrix(courses_attributes):
    name_courses= list(courses_attributes.index)
    sim = pd.DataFrame(cosine_similarity(courses_attributes), columns=name_courses, index=name_courses)
    return sim

# %% [markdown]
# ##### Calculating similarity by taking into account what user already rated

# %%
def user_pref_sim_matrix(topic_attr, user_pref):
    
    #Sort by index preferences of users
    #Create dataframe copy with only course id and ratings
    user = user_preferences.sort_values(by = ['id'])

    #Create new dataframe with the course_attributes and user_preferences appended
    #Add 0 for indexes that have not been rated
    df = pd.DataFrame()
    df = df.append(topic_attributes)
    df['Num_Attr'] = df.drop('id', axis=1).sum(axis=1)
    df = df.merge(user, on=['id', 'course_title'], how='left').fillna(0)

    user_rating = df[['rating']].copy() 

    #Get number columns to use in operations
    column_values = len(df.columns)

    #Create weighted matrix
    weighted_matrix = pd.DataFrame(df.iloc[:,2:column_values - 3].values/pd.DataFrame([math.sqrt(i) for i in df.iloc[:,column_values - 2].values]).values)

    #Calculate like scores for user
    user_likes_score = pd.DataFrame((weighted_matrix.values*user_rating.values).sum(axis=0)).T

    #Calculate predictions for user
    pred_user=(df.iloc[:,2:column_values - 3].values*user_likes_score.values).sum(axis=1)
    df["pred_user"]=pred_user

    #Display top 5 predictions
    predictions = df.loc[df['rating'] == 0].nlargest(5, 'pred_user')[['course_title', 'pred_user']]
    
    return predictions

# %% [markdown]
# #### Show courses to user, ordered by level

# %%
list_courses = levels_filter(specific_subject)
merged_list = pd.concat(list_courses)
merged_list
# Out:
#                                                      id  \
# course_title
# Introduction to Accounting : Mastering Financia...   22
# Accounting & Financial Statement Analysis: Comp...   43
# Learn Accounting. Understand Business.               54
# Introduction to Accounting: The Language of Bus...   64
# Basic Excel for Basic Bookkeeping and Accounting     65
# Accounting for Beginners : Learn Basics in unde...   79
# Accounting: Get Hired Without Work Experience        98
# Shark Accounting - Building a Business by the N...  103
# Accounting in 60 Minutes - A Brief Introduction     105
# Fundamentals of Accounting                          106
# Accounting 101: How to read an Accounting Balan...  107
# Introduction to bookkeeping and Accounting          108
# Accounting Basics in 66 Minutes (absolutely for...  114
# Introductory Financial Accounting                   122
# Accounting Standards Basics (Professional Cours...  124
# Introduction to Bookkeeping (Accounting)            148
# Financial Accounting - A Brief Introduction         160
# Accounting Concepts For Technocrats                 221
# Financial Accounting Part 2 - Passing The Class     228
# Accounting for School Students                      232
# Accounting and Business Basics                      268
# Financial Accounting Part I - Passing the Class     286
# Financial Accounting Made Easy for All              295
# Professional Bookkeeping & Accounting 1: Sales ...  309
# Super Fast Accounting - the fastest way to do y...  317
# Learn the basics of preparing accounting statem...   93
# Advanced Accounting for Investment Banking          150
# Accounting Standard 3 - An Analysis                 162
# Accounting Books of Accounts (College Level)        170
# Learn Financial Accounting Different                178
# Accounting Bank Reconciliation Statement (Colle...  181
# Professional Bookkeeping & Accounting 4:Trial B...  188
# Introduction to Accounting - Analyzing Financia...  202
# Intermediate Accounting 1: Easy. Fast. Simple!      219
# Legal Accounting                                    231
# Accounting Simplified                               266
# Finance and Accounting for Startups                 273
# Accounting 102: Guide to Business Accounting        287
# Advanced Finance and Accounting for Startups        288
# Accounting for Depreciation (Collage Level)         298
# Tax Accounting: Difficult Topic Made Easy to Un...  115
# Working Capital Management for Entrepreneurs        216
# Certificate in MYOB AccountRight Premier 2017 C...  234
#
#                                                                                                   url  \
# course_title
# Introduction to Accounting : Mastering Financia...  https://www.udemy.com/introduction-to-accounti...
# Accounting & Financial Statement Analysis: Comp...  https://www.udemy.com/accounting-fsa-a-solid-f...
# Learn Accounting. Understand Business.              https://www.udemy.com/learn-accounting-underst...
# Introduction to Accounting: The Language of Bus...      https://www.udemy.com/learnaccountingforfree/
# Basic Excel for Basic Bookkeeping and Accounting    https://www.udemy.com/basic-excel-for-basic-bo...
# Accounting for Beginners : Learn Basics in unde...  https://www.udemy.com/accounting-for-beginners...
# Accounting: Get Hired Without Work Experience       https://www.udemy.com/accounting-get-hired-wit...
# Shark Accounting - Building a Business by the N...            https://www.udemy.com/shark-accounting/
# Accounting in 60 Minutes - A Brief Introduction     https://www.udemy.com/accounting-in-60-minutes...
# Fundamentals of Accounting                          https://www.udemy.com/fundamentals-of-accounting/
# Accounting 101: How to read an Accounting Balan...  https://www.udemy.com/financial-statements-101...
# Introduction to bookkeeping and Accounting          https://www.udemy.com/introduction-to-bookkeep...
# Accounting Basics in 66 Minutes (absolutely for...  https://www.udemy.com/accounting-through-visua...
# Introductory Financial Accounting                   https://www.udemy.com/introductory-financial-a...
# Accounting Standards Basics (Professional Cours...  https://www.udemy.com/basics-of-accounting-sta...
# Introduction to Bookkeeping (Accounting)            https://www.udemy.com/introduction-to-bookkeep...
# Financial Accounting - A Brief Introduction         https://www.udemy.com/accounting-in-less-then-...
# Accounting Concepts For Technocrats                 https://www.udemy.com/accounting-concepts-for-...
# Financial Accounting Part 2 - Passing The Class     https://www.udemy.com/financial-accounting-par...
# Accounting for School Students                       https://www.udemy.com/cash-books-in-accountancy/
# Accounting and Business Basics                      https://www.udemy.com/accounting-and-business-...
# Financial Accounting Part I - Passing the Class     https://www.udemy.com/severson-financial-accou...
# Financial Accounting Made Easy for All                     https://www.udemy.com/financialaccounting/
# Professional Bookkeeping & Accounting 1: Sales ...  https://www.udemy.com/professional-bookkeeping...
# Super Fast Accounting - the fastest way to do y...       https://www.udemy.com/super-fast-accounting/
# Learn the basics of preparing accounting statem...  https://www.udemy.com/basics-of-financial-acco...
# Advanced Accounting for Investment Banking          https://www.udemy.com/advanced-accounting-for-...
# Accounting Standard 3 - An Analysis                   https://www.udemy.com/learn-cash-flow-analysis/
# Accounting Books of Accounts (College Level)                 https://www.udemy.com/books-of-accounts/
# Learn Financial Accounting Different                https://www.udemy.com/learn-financial-accounti...
# Accounting Bank Reconciliation Statement (Colle...  https://www.udemy.com/bankreconciliationstatem...
# Professional Bookkeeping & Accounting 4:Trial B...  https://www.udemy.com/professional-bookkeeping...
# Introduction to Accounting - Analyzing Financia...  https://www.udemy.com/introduction-to-accounti...
# Intermediate Accounting 1: Easy. Fast. Simple!          https://www.udemy.com/intermediateaccounting/
# Legal Accounting                                           https://www.udemy.com/solicitors-accounts/
# Accounting Simplified                                    https://www.udemy.com/accounting-simplified/
# Finance and Accounting for Startups                 https://www.udemy.com/finance-and-accounting-f...
# Accounting 102: Guide to Business Accounting        https://www.udemy.com/accounting-skills-a-busi...
# Advanced Finance and Accounting for Startups        https://www.udemy.com/advanced-finance-and-acc...
# Accounting for Depreciation (Collage Level)            https://www.udemy.com/depreciation-accounting/
# Tax Accounting: Difficult Topic Made Easy to Un...               https://www.udemy.com/taxaccounting/
# Working Capital Management for Entrepreneurs        https://www.udemy.com/working-capital-manageme...
# Certificate in MYOB AccountRight Premier 2017 C...  https://www.udemy.com/certificate-in-myob-acco...
#
#                                                                  level  \
# course_title
# Introduction to Accounting : Mastering Financia...      Beginner Level
# Accounting & Financial Statement Analysis: Comp...      Beginner Level
# Learn Accounting. Understand Business.                  Beginner Level
# Introduction to Accounting: The Language of Bus...      Beginner Level
# Basic Excel for Basic Bookkeeping and Accounting        Beginner Level
# Accounting for Beginners : Learn Basics in unde...      Beginner Level
# Accounting: Get Hired Without Work Experience           Beginner Level
# Shark Accounting - Building a Business by the N...      Beginner Level
# Accounting in 60 Minutes - A Brief Introduction         Beginner Level
# Fundamentals of Accounting                              Beginner Level
# Accounting 101: How to read an Accounting Balan...      Beginner Level
# Introduction to bookkeeping and Accounting              Beginner Level
# Accounting Basics in 66 Minutes (absolutely for...      Beginner Level
# Introductory Financial Accounting                       Beginner Level
# Accounting Standards Basics (Professional Cours...      Beginner Level
# Introduction to Bookkeeping (Accounting)                Beginner Level
# Financial Accounting - A Brief Introduction             Beginner Level
# Accounting Concepts For Technocrats                     Beginner Level
# Financial Accounting Part 2 - Passing The Class         Beginner Level
# Accounting for School Students                          Beginner Level
# Accounting and Business Basics                          Beginner Level
# Financial Accounting Part I - Passing the Class         Beginner Level
# Financial Accounting Made Easy for All                  Beginner Level
# Professional Bookkeeping & Accounting 1: Sales ...      Beginner Level
# Super Fast Accounting - the fastest way to do y...      Beginner Level
# Learn the basics of preparing accounting statem...  Intermediate Level
# Advanced Accounting for Investment Banking          Intermediate Level
# Accounting Standard 3 - An Analysis                 Intermediate Level
# Accounting Books of Accounts (College Level)        Intermediate Level
# Learn Financial Accounting Different                Intermediate Level
# Accounting Bank Reconciliation Statement (Colle...  Intermediate Level
# Professional Bookkeeping & Accounting 4:Trial B...  Intermediate Level
# Introduction to Accounting - Analyzing Financia...  Intermediate Level
# Intermediate Accounting 1: Easy. Fast. Simple!      Intermediate Level
# Legal Accounting                                    Intermediate Level
# Accounting Simplified                               Intermediate Level
# Finance and Accounting for Startups                 Intermediate Level
# Accounting 102: Guide to Business Accounting        Intermediate Level
# Advanced Finance and Accounting for Startups        Intermediate Level
# Accounting for Depreciation (Collage Level)         Intermediate Level
# Tax Accounting: Difficult Topic Made Easy to Un...        Expert Level
# Working Capital Management for Entrepreneurs              Expert Level
# Certificate in MYOB AccountRight Premier 2017 C...        Expert Level
#
#                                                         main_subject  \
# course_title
# Introduction to Accounting : Mastering Financia...  Business Finance
# Accounting & Financial Statement Analysis: Comp...  Business Finance
# Learn Accounting. Understand Business.              Business Finance
# Introduction to Accounting: The Language of Bus...  Business Finance
# Basic Excel for Basic Bookkeeping and Accounting    Business Finance
# Accounting for Beginners : Learn Basics in unde...  Business Finance
# Accounting: Get Hired Without Work Experience       Business Finance
# Shark Accounting - Building a Business by the N...  Business Finance
# Accounting in 60 Minutes - A Brief Introduction     Business Finance
# Fundamentals of Accounting                          Business Finance
# Accounting 101: How to read an Accounting Balan...  Business Finance
# Introduction to bookkeeping and Accounting          Business Finance
# Accounting Basics in 66 Minutes (absolutely for...  Business Finance
# Introductory Financial Accounting                   Business Finance
# Accounting Standards Basics (Professional Cours...  Business Finance
# Introduction to Bookkeeping (Accounting)            Business Finance
# Financial Accounting - A Brief Introduction         Business Finance
# Accounting Concepts For Technocrats                 Business Finance
# Financial Accounting Part 2 - Passing The Class     Business Finance
# Accounting for School Students                      Business Finance
# Accounting and Business Basics                      Business Finance
# Financial Accounting Part I - Passing the Class     Business Finance
# Financial Accounting Made Easy for All              Business Finance
# Professional Bookkeeping & Accounting 1: Sales ...  Business Finance
# Super Fast Accounting - the fastest way to do y...  Business Finance
# Learn the basics of preparing accounting statem...  Business Finance
# Advanced Accounting for Investment Banking          Business Finance
# Accounting Standard 3 - An Analysis                 Business Finance
# Accounting Books of Accounts (College Level)        Business Finance
# Learn Financial Accounting Different                Business Finance
# Accounting Bank Reconciliation Statement (Colle...  Business Finance
# Professional Bookkeeping & Accounting 4:Trial B...  Business Finance
# Introduction to Accounting - Analyzing Financia...  Business Finance
# Intermediate Accounting 1: Easy. Fast. Simple!      Business Finance
# Legal Accounting                                    Business Finance
# Accounting Simplified                               Business Finance
# Finance and Accounting for Startups                 Business Finance
# Accounting 102: Guide to Business Accounting        Business Finance
# Advanced Finance and Accounting for Startups        Business Finance
# Accounting for Depreciation (Collage Level)         Business Finance
# Tax Accounting: Difficult Topic Made Easy to Un...  Business Finance
# Working Capital Management for Entrepreneurs        Business Finance
# Certificate in MYOB AccountRight Premier 2017 C...  Business Finance
#
#                                                    specific_subject
# course_title
# Introduction to Accounting : Mastering Financia...       Accounting
# Accounting & Financial Statement Analysis: Comp...       Accounting
# Learn Accounting. Understand Business.                   Accounting
# Introduction to Accounting: The Language of Bus...       Accounting
# Basic Excel for Basic Bookkeeping and Accounting         Accounting
# Accounting for Beginners : Learn Basics in unde...       Accounting
# Accounting: Get Hired Without Work Experience            Accounting
# Shark Accounting - Building a Business by the N...       Accounting
# Accounting in 60 Minutes - A Brief Introduction          Accounting
# Fundamentals of Accounting                               Accounting
# Accounting 101: How to read an Accounting Balan...       Accounting
# Introduction to bookkeeping and Accounting               Accounting
# Accounting Basics in 66 Minutes (absolutely for...       Accounting
# Introductory Financial Accounting                        Accounting
# Accounting Standards Basics (Professional Cours...       Accounting
# Introduction to Bookkeeping (Accounting)                 Accounting
# Financial Accounting - A Brief Introduction              Accounting
# Accounting Concepts For Technocrats                      Accounting
# Financial Accounting Part 2 - Passing The Class          Accounting
# Accounting for School Students                           Accounting
# Accounting and Business Basics                           Accounting
# Financial Accounting Part I - Passing the Class          Accounting
# Financial Accounting Made Easy for All                   Accounting
# Professional Bookkeeping & Accounting 1: Sales ...       Accounting
# Super Fast Accounting - the fastest way to do y...       Accounting
# Learn the basics of preparing accounting statem...       Accounting
# Advanced Accounting for Investment Banking               Accounting
# Accounting Standard 3 - An Analysis                      Accounting
# Accounting Books of Accounts (College Level)             Accounting
# Learn Financial Accounting Different                     Accounting
# Accounting Bank Reconciliation Statement (Colle...       Accounting
# Professional Bookkeeping & Accounting 4:Trial B...       Accounting
# Introduction to Accounting - Analyzing Financia...       Accounting
# Intermediate Accounting 1: Easy. Fast. Simple!           Accounting
# Legal Accounting                                         Accounting
# Accounting Simplified                                    Accounting
# Finance and Accounting for Startups                      Accounting
# Accounting 102: Guide to Business Accounting             Accounting
# Advanced Finance and Accounting for Startups             Accounting
# Accounting for Depreciation (Collage Level)              Accounting
# Tax Accounting: Difficult Topic Made Easy to Un...       Accounting
# Working Capital Management for Entrepreneurs             Accounting
# Certificate in MYOB AccountRight Premier 2017 C...       Accounting

# %% [markdown]
# ## Choose a course and display link

# %%
course = input(color.BOLD + color.UNDERLINE + "What course do you want to watch?" + color.END + " ")
# Out:
# What course do you want to watch? Legal Accounting

# %%
extract_url = all_courses.loc[[course], ["url"]].values[0]
course_url = extract_url[0]
print(color.BOLD + color.BLUE + color.UNDERLINE + course_url + color.END)
# Out:
# https://www.udemy.com/solicitors-accounts/

# %% [markdown]
# ## Ask if user liked course to store rating

# %%
user_rating = input(color.BOLD + color.UNDERLINE + "Did you like the video? (yes/no):" + color.END + " ")
# Out:
# Did you like the video? (yes/no): -5

# %%
if user_rating == "yes":
    like = 1
else:
    like = -1

# %% [markdown]
# #### Add course and rating to user's file. If new user, create new csv

# %% [markdown]
# ##### Find course id to store

# %%
extract_id = all_courses.loc[[course], ["id"]].values[0]
course_id = extract_id[0]

# %%
def update_rating(row):
    df = pd.read_csv('data/users/' + user_name + "_" + topic +".csv") 
    df = df[~df['id'].isin([row[0]])]
    updated_csv = df.to_csv('data/users/' + user_name + "_" + topic +".csv", index=False)
    return updated_csv

# %%
import csv

file_name = user_name + "_" + topic +".csv"

if path.exists('data/users/' + file_name) == True:
    with open('data/users/' + file_name, 'r') as file:
        csv_reader = csv.reader(file)
        rated = False
        for row in csv_reader:
            if course in row:
                print("You already rated this course, we'll update your rating!")
                updated_csv = update_rating(row)
                break
    
    with open('data/users/' + file_name, 'a') as filea:
        writer = csv.writer(filea)
        writer.writerow([course_id, course, like])
            
else:
    with open('data/users/' + file_name, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["id","course_title", "rating"])
        writer.writerow([course_id, course, like])
file.close()
# Out:
# You already rated this course, we'll update your rating!

# %% [markdown]
# ##### Open file with user ratings

# %%
#Open csv of user preferences if user exists for topic    
file = 'data/users/' + user_name + "_" + topic +".csv"
if path.exists(file) == True:
    user_preferences = pd.read_csv(file)
else:
    user_preferences = pd.DataFrame()

# %% [markdown]
# #### Recommend next courses based on user ratings

# %%
print(color.BOLD + "Courses recommended based on what you've rated so far: \n" + color.END)
top_pred = user_pref_sim_matrix(topic_attributes, user_preferences)
top_pred
# Out:
# Courses recommended based on what you've rated so far:
#                                           course_title  pred_user
# 279  How to Trade Forex like a Hedge Fund: Long FX ...   7.360066
# 116           Analysis of Company Financial Statements   6.913484
# 166              Best Practices in Corporate Budgeting   6.604083
# 99   Forex Trading with Fixed Risk through Options ...   6.446311
# 155  Technical Analysis - A practical approach for ...   6.336134

# %% [markdown]
# #### Show most similar courses to course user chose

# %%
print(color.BOLD + "Courses recommended based course you just took: \n" + color.END)

similarity = similarity_matrix(topic_attributes)
corr_top5=pd.DataFrame(similarity.loc[course].sort_values(ascending=False)[1:6])
corr_top5
# Out:
# Courses recommended based course you just took:
#                                                     Legal Accounting
# Accounting Simplified                                       0.999990
# Accounting 102: Guide to Business Accounting                0.999984
# How To Earn Some Bitcoin Every Time You Use A S...          0.999974
# Learn Financial Accounting Different                        0.999973
# Accounting Books of Accounts (College Level)                0.999971
